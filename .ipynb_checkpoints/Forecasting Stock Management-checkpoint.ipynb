# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
dataframe = pd.read_csv('monthly-beer-production-in-austr.csv', header=0)

# %%
dataframe.head
# Out:
# <bound method NDFrame.head of         Date  Demand
# 0    1956-01    93.2
# 1    1956-02    96.0
# 2    1956-03    95.2
# 3    1956-04    77.1
# 4    1956-05    70.9
# ..       ...     ...
# 471  1995-04   127.0
# 472  1995-05   151.0
# 473  1995-06   130.0
# 474  1995-07   119.0
# 475  1995-08   153.0
#
# [476 rows x 2 columns]>

# %%
dataframe.columns
# Out:
# Index(['Date', 'Demand'], dtype='object')

# %%
dataframe["Date"]= pd.to_datetime(dataframe["Date"])

# %%
dataframe['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
dataframe.index = dataframe['Date']

# %%
dataframe['Demand'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
year1 = dataframe[(dataframe['Date'] > '1990-01-01') & (dataframe['Date'] <= '1991-01-1')].copy()
